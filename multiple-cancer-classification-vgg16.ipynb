# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.3)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def initiateModel(noOfClasses):
    modelInput = tf.keras.applications.VGG16(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateParams(className, model, lr):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + 'VGG16.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 256):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=epochs,
      batch_size=batchSize,
      callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
def plotOutput(history, className, epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(12, 12))
    plt.subplot(3, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(3, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    plt.savefig(className + '_graph.png')

# %%
def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    
def saveModel(model, className):
    model.save(className + " - VGG16.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'../input/multi-cancer/Multi Cancer'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 20
lr = 0.001

for i in classPaths:
    print(i)
# Out:
# Cervical Cancer
# Lung and Colon Cancer
# Oral Cancer
# ALL
# Kidney Cancer
# Breast Cancer
# Lymphoma
# Brain Cancer

# %%
className = 'Cervical Cancer '
cpath = os.path.join(mpath, 'Cervical Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 25000 files belonging to 5 classes.
# 2022-04-07 01:47:54.623252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:54.713978: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:54.714740: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:54.717895: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-07 01:47:54.718988: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:54.719682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:54.720295: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:56.538328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:56.539182: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:56.539848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-07 01:47:56.540451: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# For Training :  Found 17500 images belonging to 5 classes.
#
# For Val :  Found 7500 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['cervix_dyk', 'cervix_koc', 'cervix_mep', 'cervix_pab', 'cervix_sfi']
# 2022-04-07 01:48:01.561690: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Image Shape :  (32, 256, 256, 3)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 125445
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 2022-04-07 01:48:06.214953: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 547/547 [==============================] - 196s 341ms/step - loss: 1.5959 - accuracy: 0.9221 - val_loss: 0.5907 - val_accuracy: 0.9717
#
# Epoch 00001: val_loss improved from inf to 0.59069, saving model to Cervical Cancer VGG16.h5
# Epoch 2/20
# 547/547 [==============================] - 131s 239ms/step - loss: 0.4228 - accuracy: 0.9802 - val_loss: 0.5999 - val_accuracy: 0.9751
#
# Epoch 00002: val_loss did not improve from 0.59069
# Epoch 3/20
# 547/547 [==============================] - 131s 240ms/step - loss: 0.2875 - accuracy: 0.9878 - val_loss: 0.5177 - val_accuracy: 0.9813
#
# Epoch 00003: val_loss improved from 0.59069 to 0.51773, saving model to Cervical Cancer VGG16.h5
# Epoch 4/20
# 547/547 [==============================] - 131s 240ms/step - loss: 0.2901 - accuracy: 0.9892 - val_loss: 0.3880 - val_accuracy: 0.9871
#
# Epoch 00004: val_loss improved from 0.51773 to 0.38801, saving model to Cervical Cancer VGG16.h5
# Epoch 5/20
# 547/547 [==============================] - 132s 242ms/step - loss: 0.2365 - accuracy: 0.9919 - val_loss: 0.6618 - val_accuracy: 0.9816
#
# Epoch 00005: val_loss did not improve from 0.38801
# Epoch 6/20
# 547/547 [==============================] - 131s 239ms/step - loss: 0.1508 - accuracy: 0.9946 - val_loss: 0.3793 - val_accuracy: 0.9896
#
# Epoch 00006: val_loss improved from 0.38801 to 0.37928, saving model to Cervical Cancer VGG16.h5
# Epoch 7/20
# 547/547 [==============================] - 129s 236ms/step - loss: 0.2253 - accuracy: 0.9932 - val_loss: 1.1997 - val_accuracy: 0.9775
#
# Epoch 00007: val_loss did not improve from 0.37928
# Epoch 8/20
# 547/547 [==============================] - 131s 239ms/step - loss: 0.2702 - accuracy: 0.9937 - val_loss: 0.7020 - val_accuracy: 0.9841
#
# Epoch 00008: val_loss did not improve from 0.37928
# Epoch 9/20
# 547/547 [==============================] - 131s 240ms/step - loss: 0.2816 - accuracy: 0.9931 - val_loss: 1.2817 - val_accuracy: 0.9777
#
# Epoch 00009: val_loss did not improve from 0.37928
# Epoch 10/20
# 547/547 [==============================] - 131s 240ms/step - loss: 0.1683 - accuracy: 0.9955 - val_loss: 0.6332 - val_accuracy: 0.9887
#
# Epoch 00010: val_loss did not improve from 0.37928
# Epoch 11/20
# 547/547 [==============================] - 131s 239ms/step - loss: 0.1238 - accuracy: 0.9971 - val_loss: 0.6573 - val_accuracy: 0.9883
#
# Epoch 00011: val_loss did not improve from 0.37928
# Epoch 12/20
# 547/547 [==============================] - 131s 239ms/step - loss: 0.1625 - accuracy: 0.9962 - val_loss: 0.5530 - val_accuracy: 0.9900
#
# Epoch 00012: val_loss did not improve from 0.37928
# Epoch 13/20
# 547/547 [==============================] - 132s 241ms/step - loss: 0.2467 - accuracy: 0.9951 - val_loss: 1.4807 - val_accuracy: 0.9763
#
# Epoch 00013: val_loss did not improve from 0.37928
# Epoch 14/20
# 547/547 [==============================] - 132s 240ms/step - loss: 0.1020 - accuracy: 0.9972 - val_loss: 1.0987 - val_accuracy: 0.9827
#
# Epoch 00014: val_loss did not improve from 0.37928
# Epoch 15/20
# 547/547 [==============================] - 130s 237ms/step - loss: 0.1312 - accuracy: 0.9973 - val_loss: 0.6103 - val_accuracy: 0.9904
#
# Epoch 00015: val_loss did not improve from 0.37928
# Epoch 16/20
# 547/547 [==============================] - 130s 238ms/step - loss: 0.0711 - accuracy: 0.9983 - val_loss: 0.8981 - val_accuracy: 0.9860
#
# Epoch 00016: val_loss did not improve from 0.37928
# Epoch 17/20
# 547/547 [==============================] - 130s 238ms/step - loss: 0.1064 - accuracy: 0.9977 - val_loss: 0.5287 - val_accuracy: 0.9905
#
# Epoch 00017: val_loss did not improve from 0.37928
# Epoch 18/20
# 547/547 [==============================] - 132s 241ms/step - loss: 0.1555 - accuracy: 0.9968 - val_loss: 0.6963 - val_accuracy: 0.9907
#
# Epoch 00018: val_loss did not improve from 0.37928
# Epoch 19/20
# 547/547 [==============================] - 131s 240ms/step - loss: 0.0828 - accuracy: 0.9983 - val_loss: 0.8748 - val_accuracy: 0.9884
#
# Epoch 00019: val_loss did not improve from 0.37928
# Epoch 20/20
# 547/547 [==============================] - 130s 238ms/step - loss: 0.0791 - accuracy: 0.9981 - val_loss: 0.8595 - val_accuracy: 0.9877
#
# Epoch 00020: val_loss did not improve from 0.37928
# 235/235 [==============================] - 40s 169ms/step - loss: 0.8595 - accuracy: 0.9877
# Accuracy on the Test Set = 98.77 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# Predicted :  [0 0 0 ... 4 4 4]

# %%
className = 'Lung and Colon Cancer '
cpath = os.path.join(mpath, 'Lung and Colon Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 25000 files belonging to 5 classes.
#
# For Training :  Found 17500 images belonging to 5 classes.
#
# For Val :  Found 7500 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 125445
# =================================================================
# Total params: 14,840,133
# Trainable params: 125,445
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 547/547 [==============================] - 192s 351ms/step - loss: 1.2802 - accuracy: 0.9401 - val_loss: 0.6334 - val_accuracy: 0.9733
#
# Epoch 00001: val_loss improved from inf to 0.63343, saving model to Lung and Colon Cancer VGG16.h5
# Epoch 2/20
# 547/547 [==============================] - 137s 251ms/step - loss: 0.4614 - accuracy: 0.9795 - val_loss: 1.1093 - val_accuracy: 0.9633
#
# Epoch 00002: val_loss did not improve from 0.63343
# Epoch 3/20
# 547/547 [==============================] - 137s 251ms/step - loss: 0.3394 - accuracy: 0.9875 - val_loss: 2.4476 - val_accuracy: 0.9505
#
# Epoch 00003: val_loss did not improve from 0.63343
# Epoch 4/20
# 547/547 [==============================] - 137s 250ms/step - loss: 0.3017 - accuracy: 0.9894 - val_loss: 1.1556 - val_accuracy: 0.9744
#
# Epoch 00004: val_loss did not improve from 0.63343
# Epoch 5/20
# 547/547 [==============================] - 137s 250ms/step - loss: 0.2249 - accuracy: 0.9922 - val_loss: 0.8312 - val_accuracy: 0.9808
#
# Epoch 00005: val_loss did not improve from 0.63343
# Epoch 6/20
# 547/547 [==============================] - 137s 251ms/step - loss: 0.1408 - accuracy: 0.9948 - val_loss: 1.0111 - val_accuracy: 0.9773
#
# Epoch 00006: val_loss did not improve from 0.63343
# Epoch 7/20
# 547/547 [==============================] - 138s 253ms/step - loss: 0.1947 - accuracy: 0.9939 - val_loss: 0.9405 - val_accuracy: 0.9813
#
# Epoch 00007: val_loss did not improve from 0.63343
# Epoch 8/20
# 547/547 [==============================] - 139s 254ms/step - loss: 0.2613 - accuracy: 0.9932 - val_loss: 2.2403 - val_accuracy: 0.9703
#
# Epoch 00008: val_loss did not improve from 0.63343
# Epoch 9/20
# 547/547 [==============================] - 138s 252ms/step - loss: 0.1442 - accuracy: 0.9959 - val_loss: 1.5472 - val_accuracy: 0.9775
#
# Epoch 00009: val_loss did not improve from 0.63343
# Epoch 10/20
# 547/547 [==============================] - 138s 252ms/step - loss: 0.2263 - accuracy: 0.9950 - val_loss: 1.4267 - val_accuracy: 0.9820
#
# Epoch 00010: val_loss did not improve from 0.63343
# Epoch 11/20
# 547/547 [==============================] - 138s 252ms/step - loss: 0.2303 - accuracy: 0.9953 - val_loss: 2.7136 - val_accuracy: 0.9687
#
# Epoch 00011: val_loss did not improve from 0.63343
# Epoch 12/20
# 547/547 [==============================] - 138s 252ms/step - loss: 0.1378 - accuracy: 0.9966 - val_loss: 1.4215 - val_accuracy: 0.9815
#
# Epoch 00012: val_loss did not improve from 0.63343
# Epoch 13/20
# 547/547 [==============================] - 138s 252ms/step - loss: 0.1675 - accuracy: 0.9957 - val_loss: 2.4029 - val_accuracy: 0.9716
#
# Epoch 00013: val_loss did not improve from 0.63343
# Epoch 14/20
# 547/547 [==============================] - 138s 252ms/step - loss: 0.0797 - accuracy: 0.9977 - val_loss: 1.2075 - val_accuracy: 0.9847
#
# Epoch 00014: val_loss did not improve from 0.63343
# Epoch 15/20
# 547/547 [==============================] - 137s 250ms/step - loss: 0.1787 - accuracy: 0.9963 - val_loss: 2.7643 - val_accuracy: 0.9756
#
# Epoch 00015: val_loss did not improve from 0.63343
# Epoch 16/20
# 547/547 [==============================] - 139s 253ms/step - loss: 0.1257 - accuracy: 0.9965 - val_loss: 1.7688 - val_accuracy: 0.9815
#
# Epoch 00016: val_loss did not improve from 0.63343
# Epoch 17/20
# 547/547 [==============================] - 138s 251ms/step - loss: 0.0560 - accuracy: 0.9986 - val_loss: 1.4671 - val_accuracy: 0.9849
#
# Epoch 00017: val_loss did not improve from 0.63343
# Epoch 18/20
# 547/547 [==============================] - 138s 252ms/step - loss: 0.0253 - accuracy: 0.9991 - val_loss: 1.3661 - val_accuracy: 0.9863
#
# Epoch 00018: val_loss did not improve from 0.63343
# Epoch 19/20
# 547/547 [==============================] - 138s 253ms/step - loss: 0.1134 - accuracy: 0.9975 - val_loss: 1.9771 - val_accuracy: 0.9819
#
# Epoch 00019: val_loss did not improve from 0.63343
# Epoch 20/20
# 547/547 [==============================] - 137s 251ms/step - loss: 0.2247 - accuracy: 0.9959 - val_loss: 1.7375 - val_accuracy: 0.9831
#
# Epoch 00020: val_loss did not improve from 0.63343
# 235/235 [==============================] - 42s 177ms/step - loss: 1.7375 - accuracy: 0.9831
# Accuracy on the Test Set = 98.31 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# Predicted :  [0 1 0 ... 4 4 4]

# %%
className = 'Oral Cancer '
cpath = os.path.join(mpath, 'Oral Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10002 files belonging to 2 classes.
#
# For Training :  Found 7002 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['oral_normal', 'oral_scc']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 50178
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - 93s 425ms/step - loss: 5.9760 - accuracy: 0.7476 - val_loss: 5.5605 - val_accuracy: 0.7880
#
# Epoch 00001: val_loss improved from inf to 5.56045, saving model to Oral Cancer VGG16.h5
# Epoch 2/20
# 219/219 [==============================] - 54s 247ms/step - loss: 2.6514 - accuracy: 0.8822 - val_loss: 5.2185 - val_accuracy: 0.8190
#
# Epoch 00002: val_loss improved from 5.56045 to 5.21845, saving model to Oral Cancer VGG16.h5
# Epoch 3/20
# 219/219 [==============================] - 54s 248ms/step - loss: 1.2938 - accuracy: 0.9289 - val_loss: 6.1625 - val_accuracy: 0.8157
#
# Epoch 00003: val_loss did not improve from 5.21845
# Epoch 4/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.9028 - accuracy: 0.9472 - val_loss: 6.2948 - val_accuracy: 0.8360
#
# Epoch 00004: val_loss did not improve from 5.21845
# Epoch 5/20
# 219/219 [==============================] - 54s 248ms/step - loss: 0.8486 - accuracy: 0.9524 - val_loss: 6.1116 - val_accuracy: 0.8403
#
# Epoch 00005: val_loss did not improve from 5.21845
# Epoch 6/20
# 219/219 [==============================] - 55s 251ms/step - loss: 0.6950 - accuracy: 0.9602 - val_loss: 7.5274 - val_accuracy: 0.8217
#
# Epoch 00006: val_loss did not improve from 5.21845
# Epoch 7/20
# 219/219 [==============================] - 54s 246ms/step - loss: 0.4886 - accuracy: 0.9737 - val_loss: 7.6678 - val_accuracy: 0.8337
#
# Epoch 00007: val_loss did not improve from 5.21845
# Epoch 8/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.6852 - accuracy: 0.9663 - val_loss: 7.5992 - val_accuracy: 0.8410
#
# Epoch 00008: val_loss did not improve from 5.21845
# Epoch 9/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.7076 - accuracy: 0.9639 - val_loss: 9.2232 - val_accuracy: 0.8363
#
# Epoch 00009: val_loss did not improve from 5.21845
# Epoch 10/20
# 219/219 [==============================] - 54s 248ms/step - loss: 0.8123 - accuracy: 0.9684 - val_loss: 8.9445 - val_accuracy: 0.8330
#
# Epoch 00010: val_loss did not improve from 5.21845
# Epoch 11/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.4172 - accuracy: 0.9777 - val_loss: 8.7389 - val_accuracy: 0.8477
#
# Epoch 00011: val_loss did not improve from 5.21845
# Epoch 12/20
# 219/219 [==============================] - 54s 248ms/step - loss: 0.4083 - accuracy: 0.9800 - val_loss: 9.7487 - val_accuracy: 0.8440
#
# Epoch 00012: val_loss did not improve from 5.21845
# Epoch 13/20
# 219/219 [==============================] - 54s 246ms/step - loss: 0.6946 - accuracy: 0.9736 - val_loss: 11.7260 - val_accuracy: 0.8227
#
# Epoch 00013: val_loss did not improve from 5.21845
# Epoch 14/20
# 219/219 [==============================] - 54s 246ms/step - loss: 0.5037 - accuracy: 0.9790 - val_loss: 10.7170 - val_accuracy: 0.8467
#
# Epoch 00014: val_loss did not improve from 5.21845
# Epoch 15/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.5178 - accuracy: 0.9781 - val_loss: 12.7085 - val_accuracy: 0.8383
#
# Epoch 00015: val_loss did not improve from 5.21845
# Epoch 16/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.3729 - accuracy: 0.9850 - val_loss: 14.5706 - val_accuracy: 0.8133
#
# Epoch 00016: val_loss did not improve from 5.21845
# Epoch 17/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.8438 - accuracy: 0.9754 - val_loss: 12.5932 - val_accuracy: 0.8417
#
# Epoch 00017: val_loss did not improve from 5.21845
# Epoch 18/20
# 219/219 [==============================] - 54s 248ms/step - loss: 0.2648 - accuracy: 0.9881 - val_loss: 12.3366 - val_accuracy: 0.8437
#
# Epoch 00018: val_loss did not improve from 5.21845
# Epoch 19/20
# 219/219 [==============================] - 54s 246ms/step - loss: 0.2074 - accuracy: 0.9916 - val_loss: 13.8314 - val_accuracy: 0.8470
#
# Epoch 00019: val_loss did not improve from 5.21845
# Epoch 20/20
# 219/219 [==============================] - 54s 248ms/step - loss: 0.1893 - accuracy: 0.9917 - val_loss: 12.8165 - val_accuracy: 0.8340
#
# Epoch 00020: val_loss did not improve from 5.21845
# 94/94 [==============================] - 16s 170ms/step - loss: 12.8165 - accuracy: 0.8340
# Accuracy on the Test Set = 83.40 %
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# Predicted :  [1 0 0 ... 1 1 1]

# %%
className = 'ALL '
cpath = os.path.join(mpath, 'ALL')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 20000 files belonging to 4 classes.
#
# For Training :  Found 14000 images belonging to 4 classes.
#
# For Val :  Found 6000 images belonging to 4 classes.
#
# No of Classes :  4
# Classes :  ['all_benign', 'all_early', 'all_pre', 'all_pro']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 100356
# =================================================================
# Total params: 14,815,044
# Trainable params: 100,356
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 438/438 [==============================] - 180s 409ms/step - loss: 1.0879 - accuracy: 0.9471 - val_loss: 0.2706 - val_accuracy: 0.9817
#
# Epoch 00001: val_loss improved from inf to 0.27059, saving model to ALL VGG16.h5
# Epoch 2/20
# 438/438 [==============================] - 101s 231ms/step - loss: 0.2369 - accuracy: 0.9884 - val_loss: 0.4438 - val_accuracy: 0.9813
#
# Epoch 00002: val_loss did not improve from 0.27059
# Epoch 3/20
# 438/438 [==============================] - 101s 230ms/step - loss: 0.1616 - accuracy: 0.9915 - val_loss: 0.1930 - val_accuracy: 0.9907
#
# Epoch 00003: val_loss improved from 0.27059 to 0.19295, saving model to ALL VGG16.h5
# Epoch 4/20
# 438/438 [==============================] - 100s 229ms/step - loss: 0.1162 - accuracy: 0.9944 - val_loss: 0.6286 - val_accuracy: 0.9818
#
# Epoch 00004: val_loss did not improve from 0.19295
# Epoch 5/20
# 438/438 [==============================] - 100s 229ms/step - loss: 0.2229 - accuracy: 0.9911 - val_loss: 0.4459 - val_accuracy: 0.9872
#
# Epoch 00005: val_loss did not improve from 0.19295
# Epoch 6/20
# 438/438 [==============================] - 101s 231ms/step - loss: 0.1379 - accuracy: 0.9949 - val_loss: 0.3075 - val_accuracy: 0.9913
#
# Epoch 00006: val_loss did not improve from 0.19295
# Epoch 7/20
# 438/438 [==============================] - 101s 230ms/step - loss: 0.0632 - accuracy: 0.9976 - val_loss: 0.2032 - val_accuracy: 0.9937
#
# Epoch 00007: val_loss did not improve from 0.19295
# Epoch 8/20
# 438/438 [==============================] - 101s 230ms/step - loss: 0.0865 - accuracy: 0.9967 - val_loss: 0.4959 - val_accuracy: 0.9895
#
# Epoch 00008: val_loss did not improve from 0.19295
# Epoch 9/20
# 438/438 [==============================] - 100s 229ms/step - loss: 0.2038 - accuracy: 0.9935 - val_loss: 0.3974 - val_accuracy: 0.9905
#
# Epoch 00009: val_loss did not improve from 0.19295
# Epoch 10/20
# 438/438 [==============================] - 102s 233ms/step - loss: 0.1109 - accuracy: 0.9969 - val_loss: 0.4146 - val_accuracy: 0.9920
#
# Epoch 00010: val_loss did not improve from 0.19295
# Epoch 11/20
# 438/438 [==============================] - 102s 232ms/step - loss: 0.0747 - accuracy: 0.9981 - val_loss: 0.2419 - val_accuracy: 0.9943
#
# Epoch 00011: val_loss did not improve from 0.19295
# Epoch 12/20
# 438/438 [==============================] - 101s 230ms/step - loss: 0.1259 - accuracy: 0.9966 - val_loss: 0.8886 - val_accuracy: 0.9877
#
# Epoch 00012: val_loss did not improve from 0.19295
# Epoch 13/20
# 438/438 [==============================] - 101s 231ms/step - loss: 0.1461 - accuracy: 0.9965 - val_loss: 0.8051 - val_accuracy: 0.9852
#
# Epoch 00013: val_loss did not improve from 0.19295
# Epoch 14/20
# 438/438 [==============================] - 101s 230ms/step - loss: 0.1381 - accuracy: 0.9968 - val_loss: 0.5904 - val_accuracy: 0.9913
#
# Epoch 00014: val_loss did not improve from 0.19295
# Epoch 15/20
# 438/438 [==============================] - 101s 230ms/step - loss: 0.1175 - accuracy: 0.9974 - val_loss: 1.0307 - val_accuracy: 0.9873
#
# Epoch 00015: val_loss did not improve from 0.19295
# Epoch 16/20
# 438/438 [==============================] - 100s 228ms/step - loss: 0.0101 - accuracy: 0.9995 - val_loss: 0.3245 - val_accuracy: 0.9943
#
# Epoch 00016: val_loss did not improve from 0.19295
# Epoch 17/20
# 438/438 [==============================] - 100s 228ms/step - loss: 5.9605e-11 - accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.9943
#
# Epoch 00017: val_loss did not improve from 0.19295
# Epoch 18/20
# 438/438 [==============================] - 101s 232ms/step - loss: 5.9605e-11 - accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.9943
#
# Epoch 00018: val_loss did not improve from 0.19295
# Epoch 19/20
# 438/438 [==============================] - 101s 231ms/step - loss: 5.9605e-11 - accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.9943
#
# Epoch 00019: val_loss did not improve from 0.19295
# Epoch 20/20
# 438/438 [==============================] - 100s 229ms/step - loss: 5.9605e-11 - accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.9943
#
# Epoch 00020: val_loss did not improve from 0.19295
# 188/188 [==============================] - 31s 163ms/step - loss: 0.3245 - accuracy: 0.9943
# Accuracy on the Test Set = 99.43 %
# Model Saved!
# True :  [0 0 0 ... 3 3 3]
# Predicted :  [0 0 0 ... 3 3 3]

# %%
className = 'Kidney Cancer '
cpath = os.path.join(mpath, 'Kidney Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 7000 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['kidney_normal', 'kidney_tumor']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 50178
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - 84s 382ms/step - loss: 0.5477 - accuracy: 0.9777 - val_loss: 9.3409 - val_accuracy: 0.8240
#
# Epoch 00001: val_loss improved from inf to 9.34092, saving model to Kidney Cancer VGG16.h5
# Epoch 2/20
# 219/219 [==============================] - 50s 229ms/step - loss: 0.0916 - accuracy: 0.9956 - val_loss: 6.3492 - val_accuracy: 0.8967
#
# Epoch 00002: val_loss improved from 9.34092 to 6.34922, saving model to Kidney Cancer VGG16.h5
# Epoch 3/20
# 219/219 [==============================] - 49s 226ms/step - loss: 2.9524e-04 - accuracy: 0.9997 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00003: val_loss did not improve from 6.34922
# Epoch 4/20
# 219/219 [==============================] - 49s 225ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00004: val_loss did not improve from 6.34922
# Epoch 5/20
# 219/219 [==============================] - 50s 227ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00005: val_loss did not improve from 6.34922
# Epoch 6/20
# 219/219 [==============================] - 50s 227ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00006: val_loss did not improve from 6.34922
# Epoch 7/20
# 219/219 [==============================] - 50s 227ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00007: val_loss did not improve from 6.34922
# Epoch 8/20
# 219/219 [==============================] - 49s 225ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00008: val_loss did not improve from 6.34922
# Epoch 9/20
# 219/219 [==============================] - 51s 231ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00009: val_loss did not improve from 6.34922
# Epoch 10/20
# 219/219 [==============================] - 49s 225ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00010: val_loss did not improve from 6.34922
# Epoch 11/20
# 219/219 [==============================] - 50s 227ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00011: val_loss did not improve from 6.34922
# Epoch 12/20
# 219/219 [==============================] - 49s 225ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00012: val_loss did not improve from 6.34922
# Epoch 13/20
# 219/219 [==============================] - 50s 228ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00013: val_loss did not improve from 6.34922
# Epoch 14/20
# 219/219 [==============================] - 49s 225ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00014: val_loss did not improve from 6.34922
# Epoch 15/20
# 219/219 [==============================] - 49s 226ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00015: val_loss did not improve from 6.34922
# Epoch 16/20
# 219/219 [==============================] - 49s 225ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00016: val_loss did not improve from 6.34922
# Epoch 17/20
# 219/219 [==============================] - 50s 227ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00017: val_loss did not improve from 6.34922
# Epoch 18/20
# 219/219 [==============================] - 49s 225ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00018: val_loss did not improve from 6.34922
# Epoch 19/20
# 219/219 [==============================] - 49s 223ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00019: val_loss did not improve from 6.34922
# Epoch 20/20
# 219/219 [==============================] - 49s 223ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.9406 - val_accuracy: 0.8450
#
# Epoch 00020: val_loss did not improve from 6.34922
# 94/94 [==============================] - 15s 156ms/step - loss: 8.9406 - accuracy: 0.8450
# Accuracy on the Test Set = 84.50 %
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# Predicted :  [0 0 0 ... 1 1 1]

# %%
className = 'Breast Cancer '
cpath = os.path.join(mpath, 'Breast Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 10000 files belonging to 2 classes.
#
# For Training :  Found 7000 images belonging to 2 classes.
#
# For Val :  Found 3000 images belonging to 2 classes.
#
# No of Classes :  2
# Classes :  ['breast_benign', 'breast_malignant']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 50178
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 219/219 [==============================] - 134s 608ms/step - loss: 0.8948 - accuracy: 0.9651 - val_loss: 0.9012 - val_accuracy: 0.9790
#
# Epoch 00001: val_loss improved from inf to 0.90124, saving model to Breast Cancer VGG16.h5
# Epoch 2/20
# 219/219 [==============================] - 78s 358ms/step - loss: 0.1712 - accuracy: 0.9909 - val_loss: 0.5814 - val_accuracy: 0.9800
#
# Epoch 00002: val_loss improved from 0.90124 to 0.58136, saving model to Breast Cancer VGG16.h5
# Epoch 3/20
# 219/219 [==============================] - 79s 359ms/step - loss: 0.1435 - accuracy: 0.9930 - val_loss: 0.7750 - val_accuracy: 0.9827
#
# Epoch 00003: val_loss did not improve from 0.58136
# Epoch 4/20
# 219/219 [==============================] - 78s 356ms/step - loss: 0.0657 - accuracy: 0.9967 - val_loss: 0.7308 - val_accuracy: 0.9827
#
# Epoch 00004: val_loss did not improve from 0.58136
# Epoch 5/20
# 219/219 [==============================] - 78s 358ms/step - loss: 0.1415 - accuracy: 0.9949 - val_loss: 0.8507 - val_accuracy: 0.9837
#
# Epoch 00005: val_loss did not improve from 0.58136
# Epoch 6/20
# 219/219 [==============================] - 79s 360ms/step - loss: 0.1370 - accuracy: 0.9957 - val_loss: 1.0609 - val_accuracy: 0.9780
#
# Epoch 00006: val_loss did not improve from 0.58136
# Epoch 7/20
# 219/219 [==============================] - 78s 357ms/step - loss: 0.0317 - accuracy: 0.9986 - val_loss: 1.3027 - val_accuracy: 0.9837
#
# Epoch 00007: val_loss did not improve from 0.58136
# Epoch 8/20
# 219/219 [==============================] - 79s 361ms/step - loss: 0.0156 - accuracy: 0.9991 - val_loss: 0.9490 - val_accuracy: 0.9853
#
# Epoch 00008: val_loss did not improve from 0.58136
# Epoch 9/20
# 219/219 [==============================] - 78s 358ms/step - loss: 0.1000 - accuracy: 0.9961 - val_loss: 1.4946 - val_accuracy: 0.9847
#
# Epoch 00009: val_loss did not improve from 0.58136
# Epoch 10/20
# 219/219 [==============================] - 78s 358ms/step - loss: 0.0605 - accuracy: 0.9977 - val_loss: 0.9518 - val_accuracy: 0.9797
#
# Epoch 00010: val_loss did not improve from 0.58136
# Epoch 11/20
# 219/219 [==============================] - 79s 360ms/step - loss: 0.0295 - accuracy: 0.9993 - val_loss: 1.0656 - val_accuracy: 0.9840
#
# Epoch 00011: val_loss did not improve from 0.58136
# Epoch 12/20
# 219/219 [==============================] - 79s 360ms/step - loss: 0.0129 - accuracy: 0.9991 - val_loss: 2.0103 - val_accuracy: 0.9813
#
# Epoch 00012: val_loss did not improve from 0.58136
# Epoch 13/20
# 219/219 [==============================] - 79s 360ms/step - loss: 0.1202 - accuracy: 0.9971 - val_loss: 1.2994 - val_accuracy: 0.9797
#
# Epoch 00013: val_loss did not improve from 0.58136
# Epoch 14/20
# 219/219 [==============================] - 78s 359ms/step - loss: 0.0355 - accuracy: 0.9987 - val_loss: 1.3844 - val_accuracy: 0.9823
#
# Epoch 00014: val_loss did not improve from 0.58136
# Epoch 15/20
# 219/219 [==============================] - 78s 356ms/step - loss: 0.0906 - accuracy: 0.9977 - val_loss: 1.2680 - val_accuracy: 0.9810
#
# Epoch 00015: val_loss did not improve from 0.58136
# Epoch 16/20
# 219/219 [==============================] - 79s 361ms/step - loss: 0.1162 - accuracy: 0.9976 - val_loss: 1.1470 - val_accuracy: 0.9850
#
# Epoch 00016: val_loss did not improve from 0.58136
# Epoch 17/20
# 219/219 [==============================] - 78s 358ms/step - loss: 0.0251 - accuracy: 0.9989 - val_loss: 1.7169 - val_accuracy: 0.9850
#
# Epoch 00017: val_loss did not improve from 0.58136
# Epoch 18/20
# 219/219 [==============================] - 79s 361ms/step - loss: 0.0090 - accuracy: 0.9999 - val_loss: 1.1550 - val_accuracy: 0.9873
#
# Epoch 00018: val_loss did not improve from 0.58136
# Epoch 19/20
# 219/219 [==============================] - 79s 361ms/step - loss: 3.4060e-11 - accuracy: 1.0000 - val_loss: 1.1550 - val_accuracy: 0.9873
#
# Epoch 00019: val_loss did not improve from 0.58136
# Epoch 20/20
# 219/219 [==============================] - 78s 358ms/step - loss: 3.4060e-11 - accuracy: 1.0000 - val_loss: 1.1550 - val_accuracy: 0.9873
#
# Epoch 00020: val_loss did not improve from 0.58136
# 94/94 [==============================] - 24s 254ms/step - loss: 1.1550 - accuracy: 0.9873
# Accuracy on the Test Set = 98.73 %
# Model Saved!
# True :  [0 0 0 ... 1 1 1]
# Predicted :  [0 0 0 ... 1 1 1]

# %%
className = 'Lymphoma '
cpath = os.path.join(mpath, 'Lymphoma')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 15000 files belonging to 3 classes.
#
# For Training :  Found 10500 images belonging to 3 classes.
#
# For Val :  Found 4500 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['lymph_cll', 'lymph_fl', 'lymph_mcl']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 75267
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 329/329 [==============================] - 151s 457ms/step - loss: 4.9811 - accuracy: 0.6592 - val_loss: 3.0513 - val_accuracy: 0.7627
#
# Epoch 00001: val_loss improved from inf to 3.05128, saving model to Lymphoma VGG16.h5
# Epoch 2/20
# 329/329 [==============================] - 90s 272ms/step - loss: 2.2552 - accuracy: 0.8337 - val_loss: 2.8135 - val_accuracy: 0.8024
#
# Epoch 00002: val_loss improved from 3.05128 to 2.81355, saving model to Lymphoma VGG16.h5
# Epoch 3/20
# 329/329 [==============================] - 89s 271ms/step - loss: 1.7129 - accuracy: 0.8742 - val_loss: 2.6140 - val_accuracy: 0.8340
#
# Epoch 00003: val_loss improved from 2.81355 to 2.61398, saving model to Lymphoma VGG16.h5
# Epoch 4/20
# 329/329 [==============================] - 90s 274ms/step - loss: 1.1077 - accuracy: 0.9163 - val_loss: 3.6710 - val_accuracy: 0.8120
#
# Epoch 00004: val_loss did not improve from 2.61398
# Epoch 5/20
# 329/329 [==============================] - 90s 274ms/step - loss: 0.9258 - accuracy: 0.9298 - val_loss: 3.5866 - val_accuracy: 0.8189
#
# Epoch 00005: val_loss did not improve from 2.61398
# Epoch 6/20
# 329/329 [==============================] - 90s 273ms/step - loss: 1.0274 - accuracy: 0.9273 - val_loss: 3.0714 - val_accuracy: 0.8418
#
# Epoch 00006: val_loss did not improve from 2.61398
# Epoch 7/20
# 329/329 [==============================] - 90s 272ms/step - loss: 0.8029 - accuracy: 0.9458 - val_loss: 3.7722 - val_accuracy: 0.8338
#
# Epoch 00007: val_loss did not improve from 2.61398
# Epoch 8/20
# 329/329 [==============================] - 89s 271ms/step - loss: 0.7640 - accuracy: 0.9494 - val_loss: 6.7661 - val_accuracy: 0.7716
#
# Epoch 00008: val_loss did not improve from 2.61398
# Epoch 9/20
# 329/329 [==============================] - 89s 272ms/step - loss: 0.6198 - accuracy: 0.9550 - val_loss: 4.0299 - val_accuracy: 0.8400
#
# Epoch 00009: val_loss did not improve from 2.61398
# Epoch 10/20
# 329/329 [==============================] - 90s 273ms/step - loss: 0.7469 - accuracy: 0.9536 - val_loss: 5.3112 - val_accuracy: 0.8231
#
# Epoch 00010: val_loss did not improve from 2.61398
# Epoch 11/20
# 329/329 [==============================] - 89s 272ms/step - loss: 0.5569 - accuracy: 0.9624 - val_loss: 5.0673 - val_accuracy: 0.8316
#
# Epoch 00011: val_loss did not improve from 2.61398
# Epoch 12/20
# 329/329 [==============================] - 90s 273ms/step - loss: 0.4798 - accuracy: 0.9670 - val_loss: 4.1596 - val_accuracy: 0.8551
#
# Epoch 00012: val_loss did not improve from 2.61398
# Epoch 13/20
# 329/329 [==============================] - 89s 272ms/step - loss: 1.2857 - accuracy: 0.9414 - val_loss: 5.0915 - val_accuracy: 0.8544
#
# Epoch 00013: val_loss did not improve from 2.61398
# Epoch 14/20
# 329/329 [==============================] - 90s 273ms/step - loss: 0.6000 - accuracy: 0.9682 - val_loss: 5.2933 - val_accuracy: 0.8409
#
# Epoch 00014: val_loss did not improve from 2.61398
# Epoch 15/20
# 329/329 [==============================] - 90s 275ms/step - loss: 0.6321 - accuracy: 0.9669 - val_loss: 5.8844 - val_accuracy: 0.8411
#
# Epoch 00015: val_loss did not improve from 2.61398
# Epoch 16/20
# 329/329 [==============================] - 90s 272ms/step - loss: 0.4910 - accuracy: 0.9713 - val_loss: 4.9164 - val_accuracy: 0.8556
#
# Epoch 00016: val_loss did not improve from 2.61398
# Epoch 17/20
# 329/329 [==============================] - 89s 271ms/step - loss: 0.4610 - accuracy: 0.9741 - val_loss: 5.2219 - val_accuracy: 0.8522
#
# Epoch 00017: val_loss did not improve from 2.61398
# Epoch 18/20
# 329/329 [==============================] - 89s 271ms/step - loss: 0.3703 - accuracy: 0.9784 - val_loss: 5.4035 - val_accuracy: 0.8547
#
# Epoch 00018: val_loss did not improve from 2.61398
# Epoch 19/20
# 329/329 [==============================] - 90s 273ms/step - loss: 0.2633 - accuracy: 0.9834 - val_loss: 4.6754 - val_accuracy: 0.8629
#
# Epoch 00019: val_loss did not improve from 2.61398
# Epoch 20/20
# 329/329 [==============================] - 91s 277ms/step - loss: 0.6281 - accuracy: 0.9710 - val_loss: 5.2930 - val_accuracy: 0.8613
#
# Epoch 00020: val_loss did not improve from 2.61398
# 141/141 [==============================] - 28s 195ms/step - loss: 5.2930 - accuracy: 0.8613
# Accuracy on the Test Set = 86.13 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# Predicted :  [0 0 0 ... 0 2 2]

# %%
className = 'Brain Cancer '
cpath = os.path.join(mpath, 'Brain Cancer')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
curModel = initiateModel(noOfClasses)
modelSummary(curModel)
curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=256)
plotOutput(curHistory, className, gEpochs)
evalModel(curModel)
saveModel(curModel, className)
callPlot(curModel, className, class_names)
# Out:
# Total :  Found 15000 files belonging to 3 classes.
#
# For Training :  Found 10500 images belonging to 3 classes.
#
# For Val :  Found 4500 images belonging to 3 classes.
#
# No of Classes :  3
# Classes :  ['brain_glioma', 'brain_menin', 'brain_tumor']
# Image Shape :  (32, 256, 256, 3)
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 75267
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/20
# 329/329 [==============================] - 121s 366ms/step - loss: 2.0267 - accuracy: 0.8985 - val_loss: 1.4915 - val_accuracy: 0.9318
#
# Epoch 00001: val_loss improved from inf to 1.49145, saving model to Brain Cancer VGG16.h5
# Epoch 2/20
# 329/329 [==============================] - 72s 218ms/step - loss: 0.9226 - accuracy: 0.9550 - val_loss: 2.7911 - val_accuracy: 0.9140
#
# Epoch 00002: val_loss did not improve from 1.49145
# Epoch 3/20
# 329/329 [==============================] - 72s 219ms/step - loss: 0.4825 - accuracy: 0.9747 - val_loss: 1.4266 - val_accuracy: 0.9480
#
# Epoch 00003: val_loss improved from 1.49145 to 1.42660, saving model to Brain Cancer VGG16.h5
# Epoch 4/20
# 329/329 [==============================] - 71s 216ms/step - loss: 0.4109 - accuracy: 0.9787 - val_loss: 2.0074 - val_accuracy: 0.9453
#
# Epoch 00004: val_loss did not improve from 1.42660
# Epoch 5/20
# 329/329 [==============================] - 71s 215ms/step - loss: 0.4114 - accuracy: 0.9814 - val_loss: 1.2709 - val_accuracy: 0.9629
#
# Epoch 00005: val_loss improved from 1.42660 to 1.27088, saving model to Brain Cancer VGG16.h5
# Epoch 6/20
# 329/329 [==============================] - 72s 217ms/step - loss: 0.2765 - accuracy: 0.9870 - val_loss: 1.1326 - val_accuracy: 0.9669
#
# Epoch 00006: val_loss improved from 1.27088 to 1.13256, saving model to Brain Cancer VGG16.h5
# Epoch 7/20
# 329/329 [==============================] - 71s 217ms/step - loss: 0.1897 - accuracy: 0.9910 - val_loss: 2.1268 - val_accuracy: 0.9476
#
# Epoch 00007: val_loss did not improve from 1.13256
# Epoch 8/20
# 329/329 [==============================] - 71s 214ms/step - loss: 0.2132 - accuracy: 0.9895 - val_loss: 1.7254 - val_accuracy: 0.9596
#
# Epoch 00008: val_loss did not improve from 1.13256
# Epoch 9/20
# 329/329 [==============================] - 72s 217ms/step - loss: 0.2906 - accuracy: 0.9884 - val_loss: 2.2051 - val_accuracy: 0.9567
#
# Epoch 00009: val_loss did not improve from 1.13256
# Epoch 10/20
# 329/329 [==============================] - 70s 214ms/step - loss: 0.2552 - accuracy: 0.9906 - val_loss: 2.2505 - val_accuracy: 0.9540
#
# Epoch 00010: val_loss did not improve from 1.13256
# Epoch 11/20
# 329/329 [==============================] - 71s 216ms/step - loss: 0.2397 - accuracy: 0.9918 - val_loss: 1.9110 - val_accuracy: 0.9640
#
# Epoch 00011: val_loss did not improve from 1.13256
# Epoch 12/20
# 329/329 [==============================] - 71s 215ms/step - loss: 0.3220 - accuracy: 0.9895 - val_loss: 3.0634 - val_accuracy: 0.9524
#
# Epoch 00012: val_loss did not improve from 1.13256
# Epoch 13/20
# 329/329 [==============================] - 71s 214ms/step - loss: 0.2506 - accuracy: 0.9919 - val_loss: 2.3260 - val_accuracy: 0.9647
#
# Epoch 00013: val_loss did not improve from 1.13256
# Epoch 14/20
# 329/329 [==============================] - 71s 215ms/step - loss: 0.1947 - accuracy: 0.9935 - val_loss: 2.1424 - val_accuracy: 0.9667
#
# Epoch 00014: val_loss did not improve from 1.13256
# Epoch 15/20
# 329/329 [==============================] - 70s 214ms/step - loss: 0.1697 - accuracy: 0.9951 - val_loss: 4.6734 - val_accuracy: 0.9396
#
# Epoch 00015: val_loss did not improve from 1.13256
# Epoch 16/20
# 329/329 [==============================] - 72s 218ms/step - loss: 0.2293 - accuracy: 0.9928 - val_loss: 2.4958 - val_accuracy: 0.9662
#
# Epoch 00016: val_loss did not improve from 1.13256
# Epoch 17/20
# 329/329 [==============================] - 71s 216ms/step - loss: 0.1936 - accuracy: 0.9941 - val_loss: 2.5160 - val_accuracy: 0.9680
#
# Epoch 00017: val_loss did not improve from 1.13256
# Epoch 18/20
# 329/329 [==============================] - 71s 215ms/step - loss: 0.1825 - accuracy: 0.9939 - val_loss: 2.1285 - val_accuracy: 0.9689
#
# Epoch 00018: val_loss did not improve from 1.13256
# Epoch 19/20
# 329/329 [==============================] - 70s 213ms/step - loss: 0.1251 - accuracy: 0.9956 - val_loss: 3.4141 - val_accuracy: 0.9618
#
# Epoch 00019: val_loss did not improve from 1.13256
# Epoch 20/20
# 329/329 [==============================] - 71s 217ms/step - loss: 0.3167 - accuracy: 0.9921 - val_loss: 2.9704 - val_accuracy: 0.9660
#
# Epoch 00020: val_loss did not improve from 1.13256
# 141/141 [==============================] - 21s 150ms/step - loss: 2.9704 - accuracy: 0.9660
# Accuracy on the Test Set = 96.60 %
# Model Saved!
# True :  [0 0 0 ... 2 2 2]
# Predicted :  [0 0 0 ... 2 2 2]
